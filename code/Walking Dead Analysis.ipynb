# %%
from bs4 import BeautifulSoup
import pandas as pd
from sklearn import linear_model
import sklearn as sk
import sklearn.tree as tree
import statsmodels.api as sm
import pydotplus
import matplotlib
import matplotlib.pyplot as plt
import requests
import re
import numpy as np

# %matplotlib inline

# %%
# reads in a table with a list of episodes
df_episodes = pd.read_csv('../data/episodes.csv')

# this is the pages where we will get the url for each characters page
character_list_url = 'http://walkingdead.wikia.com/wiki/TV_Series_Characters'
episode_list_url = ''
base_url = 'http://walkingdead.wikia.com'
r = requests.get(character_list_url)
s = BeautifulSoup(r.text, 'lxml')

attribute_list = ['gender', 'hair', 'age', 'ethnicity', 'status', 'series lifespan']
drop_list = ['/wiki/Tim_(TV_Series)', '/wiki/Big_Tony_(TV_Series)']
character_list = ['Glenn Rhee', 'Maggie Greene', 'Daryl Dixon', 'Rick Grimes', 'Abraham Ford', \
                  'Carl Grimes', 'Michonne', 'Rosita Espinosa', 'Sasha Williams', 'Aaron', 'Eugene Porter']

# %%
# finds the urls of all the character
chars = s.findAll(class_ = 'image image-thumbnail link-internal')
characters_urls = []
for i in range(len(chars)):
    if chars[i].get('href').replace('/wiki/', '') != 'Characters':
        characters_urls.append(chars[i].get('href'))
        
        
# remove character pages that are incomplete or deleted
characters_urls = [c for c in characters_urls if c not in drop_list]

# %%
# goes through the character urls
i = 0
new_row = []

r = requests.get(base_url + characters_urls[i])
s = BeautifulSoup(r.text, 'lxml')

# grabs the info box from the page
infobox = s.find(class_ = re.compile('infobox.*'))
if infobox is not None:
    text = infobox.get_text()

    # formats the text a little
    for a in attribute_list:
        text = text.replace(a + '\n', '\n' + a + ': ')

# %%
res_list = []

# goes through the characters
for character_url in characters_urls:
    print(character_url)
    
    new_row = []

    # goes to that characters page
    r = requests.get(base_url + character_url)
    s = BeautifulSoup(r.text, 'lxml')

    # grabs the info box from the page
    infobox = s.find(class_ = re.compile('infobox.*'))
    text = infobox.get_text()

    # gets the name
    new_row.append(text.split('\n')[1].strip())

    # gets each of the attributes
    for a in attribute_list:
        try:
            result = re.search(a.lower() + '\n(.*)\n', text.lower())
            new_row.append(result.group().replace(a.lower() + '\n', '').strip())          
            
        except:
            new_row.append('NA')

    # gets the first and last episode they were in
    if '" to ' in new_row[6]:
        series_lifespan = new_row[6].split('" to ')
        new_row.append(series_lifespan[0].replace('"', ''))
        new_row.append(series_lifespan[1].replace('"', '').strip())  
    else:
        new_row.append(new_row[6].replace('"', ''))
        new_row.append(new_row[6].replace('"', ''))
        
    # appends the data to the results list
    res_list.append(new_row)
# Out:
# /wiki/Rick_Grimes_(TV_Series)
# /wiki/Carl_Grimes_(TV_Series)
# /wiki/Judith_Grimes_(TV_Series)
# /wiki/Lori_Grimes_(TV_Series)
# /wiki/Lambert_Kendal_(TV_Series)
# /wiki/Shane_Walsh_(TV_Series)
# /wiki/Leon_Basset_(TV_Series)
# /wiki/Morgan_Jones_(TV_Series)
# /wiki/Jenny_Jones_(TV_Series)
# /wiki/Duane_Jones_(TV_Series)
# /wiki/Paula_(TV_Series)
# /wiki/Glenn_Rhee_(TV_Series)
# /wiki/Theodore_Douglas_(TV_Series)
# /wiki/Dale_Horvath_(TV_Series)
# /wiki/Jacqui_(TV_Series)
# /wiki/Jim_(TV_Series)
# /wiki/Carol_Peletier_(TV_Series)
# /wiki/Sophia_Peletier_(TV_Series)
# /wiki/Ed_Peletier_(TV_Series)
# /wiki/Daryl_Dixon_(TV_Series)
# /wiki/Merle_Dixon_(TV_Series)
# /wiki/Andrea_(TV_Series)
# /wiki/Amy_(TV_Series)
# /wiki/Morales_(TV_Series)
# /wiki/Miranda_Morales_(TV_Series)
# /wiki/Louis_Morales_(TV_Series)
# /wiki/Eliza_Morales_(TV_Series)
# /wiki/Guillermo_(TV_Series)
# /wiki/Jorge_(TV_Series)
# /wiki/Mr._Gilbert_(TV_Series)
# /wiki/Abuela_(TV_Series)
# /wiki/Felipe_(TV_Series)
# /wiki/Miguel_(TV_Series)
# /wiki/Vi_(TV_Series)
# /wiki/Edwin_Jenner_(TV_Series)
# /wiki/Candace_Jenner_(TV_Series)
# /wiki/Maggie_Greene_(TV_Series)
# /wiki/Beth_Greene_(TV_Series)
# /wiki/Hershel_Greene_(TV_Series)
# /wiki/Annette_Greene_(TV_Series)
# /wiki/Shawn_Greene_(TV_Series)
# /wiki/Arnold_Greene_(TV_Series)
# /wiki/Josephine_Greene_(TV_Series)
# /wiki/Patricia_(TV_Series)
# /wiki/Otis_(TV_Series)
# /wiki/Jimmy_(TV_Series)
# /wiki/Nate_(TV_Series)
# /wiki/Randall_(TV_Series)
# /wiki/Sean_(TV_Series)
# /wiki/Tony_(Season_2)
# /wiki/Dave_(TV_Series)
# /wiki/Michonne_(TV_Series)
# /wiki/Andre_Anthony_(TV_Series)
# /wiki/Mike_(TV_Series)
# /wiki/Terry_(TV_Series)
# /wiki/Axel_(TV_Series)
# /wiki/Oscar_(TV_Series)
# /wiki/Andrew_(TV_Series)
# /wiki/Tomas_(TV_Series)
# /wiki/Big_Tiny_(TV_Series)
# /wiki/Jeanette_(TV_Series)
# /wiki/Caesar_Martinez_(TV_Series)
# /wiki/Shumpert_(TV_Series)
# /wiki/Mr._Jacobson_(TV_Series)
# /wiki/Karen_(TV_Series)
# /wiki/Eryn_(TV_Series)
# /wiki/Owen_(Prison)
# /wiki/Thomas_(TV_Series)
# /wiki/Greg_(Woodbury)
# /wiki/Ms._McLeod_(TV_Series)
# /wiki/Milton_Mamet_(TV_Series)
# /wiki/Rowan_(TV_Series)
# /wiki/Dr._Stevens_(TV_Series)
# /wiki/Eileen_(TV_Series)
# /wiki/Gloria_(TV_Series)
# /wiki/Noah_(Woodbury)
# /wiki/Eric_(TV_Series)
# /wiki/Paul_(TV_Series)
# /wiki/Jody_(TV_Series)
# /wiki/Haley_(TV_Series)
# /wiki/Warren_(TV_Series)
# /wiki/Gargulio_(TV_Series)
# /wiki/Crowley_(TV_Series)
# /wiki/Philip_Blake_(TV_Series)
# /wiki/Penny_Blake_(TV_Series)
# /wiki/Mrs._Blake_(TV_Series)
# /wiki/Michael_Coleman_(TV_Series)
# /wiki/Betty_Coleman_(TV_Series)
# /wiki/Emily_Coleman_(TV_Series)
# /wiki/Richard_Foster_(TV_Series)
# /wiki/Mrs._Foster_(TV_Series)
# /wiki/Sasha_Williams_(TV_Series)
# /wiki/Tyreese_Williams_(TV_Series)
# /wiki/Allen_(TV_Series)
# /wiki/Ben_(TV_Series)
# /wiki/Donna_(TV_Series)
# /wiki/Gaines_(TV_Series)
# /wiki/Brady_(TV_Series)
# /wiki/Wilson_(TV_Series)
# /wiki/Sean_(Military)
# /wiki/Franklin_(TV_Series)
# /wiki/Welles_(TV_Series)
# /wiki/Bob_Stookey_(TV_Series)
# /wiki/Luke_(TV_Series)
# /wiki/Molly_(TV_Series)
# /wiki/Becky_(TV_Series)
# /wiki/Julio_(TV_Series)
# /wiki/Henry_(TV_Series)
# /wiki/Noris_(TV_Series)
# /wiki/Caleb_Subramanian_(TV_Series)
# /wiki/David_(TV_Series)
# /wiki/Chloe_(TV_Series)
# /wiki/Mr._Richards_(TV_Series)
# /wiki/Charlie_(TV_Series)
# /wiki/Patrick_(TV_Series)
# /wiki/Zach_(TV_Series)
# /wiki/Lizzie_Samuels_(TV_Series)
# /wiki/Mika_Samuels_(TV_Series)
# /wiki/Ryan_Samuels_(TV_Series)
# /wiki/Sam_(TV_Series)
# /wiki/Christopher_(TV_Series)
# /wiki/Ana_(TV_Series)
# /wiki/Clara_(TV_Series)
# /wiki/Tara_Chambler_(TV_Series)
# /wiki/Lilly_Chambler_(TV_Series)
# /wiki/Meghan_Chambler_(TV_Series)
# /wiki/David_Chambler_(TV_Series)
# /wiki/Howard_(TV_Series)
# /wiki/Alisha_(TV_Series)
# /wiki/Ross_(TV_Series)
# /wiki/Mitch_Dolgen_(TV_Series)
# /wiki/Pete_Dolgen_(TV_Series)
# /wiki/Eugene_Porter_(TV_Series)
# /wiki/Rosita_Espinosa_(TV_Series)
# /wiki/Abraham_Ford_(TV_Series)
# /wiki/Ellen_Ford_(TV_Series)
# /wiki/A.J._Ford_(TV_Series)
# /wiki/Becca_Ford_(TV_Series)
# /wiki/Dan_(TV_Series)
# /wiki/Billy_(TV_Series)
# /wiki/Harley_(TV_Series)
# /wiki/Tony_(Claimer)
# /wiki/Joe_(TV_Series)
# /wiki/Len_(TV_Series)
# /wiki/Lou_(TV_Series)
# /wiki/Martin_(TV_Series)
# /wiki/Greg_(Terminus)
# /wiki/Theresa_(TV_Series)
# /wiki/Albert_(TV_Series)
# /wiki/Mike_(Terminus)
# /wiki/Gareth_(TV_Series)
# /wiki/Mary_(TV_Series)
# /wiki/Alex_(TV_Series)
# /wiki/Gabriel_Stokes_(TV_Series)
# /wiki/Steven_Edwards_(TV_Series)
# /wiki/Amanda_Shepherd_(TV_Series)
# /wiki/Licari_(TV_Series)
# /wiki/Franco_(TV_Series)
# /wiki/McGinley_(TV_Series)
# /wiki/Bello_(TV_Series)
# /wiki/Tanaka_(TV_Series)
# /wiki/Alvarado_(TV_Series)
# /wiki/Percy_(TV_Series)
# /wiki/Noah_(Season_5)
# /wiki/Dawn_Lerner_(TV_Series)
# /wiki/O%27Donnell_(TV_Series)
# /wiki/Bob_Lamson_(TV_Series)
# /wiki/Jeffries_(TV_Series)
# /wiki/Gorman_(TV_Series)
# /wiki/Joan_(TV_Series)
# /wiki/Gavin_Trevitt_(TV_Series)
# /wiki/Hanson_(TV_Series)
# /wiki/Eric_Raleigh_(TV_Series)
# /wiki/Enid_(TV_Series)
# /wiki/Olivia_(TV_Series)
# /wiki/Jake_(TV_Series)
# /wiki/Tobin_(TV_Series)
# /wiki/Kent_(TV_Series)
# /wiki/Barbara_(TV_Series)
# /wiki/Bruce_(TV_Series)
# /wiki/Francine_(TV_Series)
# /wiki/Heath_(TV_Series)
# /wiki/Scott_(TV_Series)
# /wiki/Anna_(TV_Series)
# /wiki/Aaron_(TV_Series)
# /wiki/Denise_Cloyd_(TV_Series)
# /wiki/Tommy_(TV_Series)
# /wiki/Annie_(TV_Series)
# /wiki/Will_(TV_Series)
# /wiki/Sturgess_(TV_Series)
# /wiki/Barnes_(TV_Series)
# /wiki/Stacy_(TV_Series)
# /wiki/Michael_(TV_Series)
# /wiki/Holly_(TV_Series)
# /wiki/Erin_(TV_Series)
# /wiki/Richards_(TV_Series)
# /wiki/Shelly_Neudermeyer_(TV_Series)
# /wiki/Carter_(TV_Series)
# /wiki/Mikey_(TV_Series)
# /wiki/Nicholas_(TV_Series)
# /wiki/Spencer_Monroe_(TV_Series)
# /wiki/Deanna_Monroe_(TV_Series)
# /wiki/Reg_Monroe_(TV_Series)
# /wiki/Aiden_Monroe_(TV_Series)
# /wiki/Ron_Anderson_(TV_Series)
# /wiki/Jessie_Anderson_(TV_Series)
# /wiki/Sam_Anderson_(TV_Series)
# /wiki/Pete_Anderson_(TV_Series)
# /wiki/Betsy_(TV_Series)
# /wiki/David_(Season_6)
# /wiki/Bob_Miller_(TV_Series)
# /wiki/Natalie_Miller_(TV_Series)
# /wiki/Owen_(Wolf)
# /wiki/Edward_(TV_Series)
# /wiki/Aphid_(TV_Series)
# /wiki/Eastman_(TV_Series)
# /wiki/Negan_(TV_Series)
# /wiki/Simon_(TV_Series)
# /wiki/Wade_(TV_Series)
# /wiki/Cam_(TV_Series)
# /wiki/Roman_(TV_Series)
# /wiki/Jiro_(TV_Series)
# /wiki/Miles_(TV_Series)
# /wiki/Neil_(TV_Series)
# /wiki/Primo_(TV_Series)
# /wiki/Paula_(Savior)
# /wiki/Michelle_(TV_Series)
# /wiki/Molly_(Savior)
# /wiki/Donnie_(TV_Series)
# /wiki/Gabe_(TV_Series)
# /wiki/Bud_(TV_Series)
# /wiki/T._(TV_Series)
# /wiki/Dwight_(TV_Series)
# /wiki/Honey_(TV_Series)
# /wiki/Tina_(TV_Series)
# /wiki/Paul_Rovia_(TV_Series)
# /wiki/Bertie_(TV_Series)
# /wiki/Harlan_Carson_(TV_Series)
# /wiki/Freddie_(TV_Series)
# /wiki/Kal_(TV_Series)
# /wiki/Eduardo_(TV_Series)
# /wiki/Gregory_(TV_Series)
# /wiki/Crystal_(TV_Series)
# /wiki/Andy_(TV_Series)
# /wiki/Wesley_(TV_Series)
# /wiki/Craig_(TV_Series)
# /wiki/Ethan_(TV_Series)
# /wiki/Ezekiel_(TV_Series)
# /wiki/Shiva_(TV_Series)
# /wiki/Nelly_(TV_Series)
# /wiki/Tabitha_(TV_Series)
# /wiki/Buttons_(TV_Series)
# /wiki/Duke_(TV_Series)
# /wiki/Flame_(TV_Series)
# /wiki/Violet_(TV_Series)
# /wiki/Carla_(TV_Series)
# /wiki/Delly_(TV_Series)
# /wiki/Joe_Sr._(TV_Series)
# /wiki/Bill_Jenkins_(TV_Series)
# /wiki/Nick_(TV_Series)
# /wiki/Erin_(TV_Series)
# /wiki/Doug_(TV_Series)
# /wiki/Louise_Bush_(TV_Series)
# /wiki/Wayne_Dunlap_(TV_Series)
# /wiki/Hannah_(Webisodes)
# /wiki/Summer_(TV_Series)
# /wiki/Callaway_(TV_Series)
# /wiki/Eddie_(TV_Series)

# %%
df = pd.DataFrame(res_list, columns = ['name'] + attribute_list + ['start_episode', 'end_episode'])

# corrects the status of some of the characters
# the wiki list some of our characters in question as alive and others as unknown
df.ix[df['name'].isin(character_list), 'status'] = 'alive'

# %%
# remove unknown
print(df.shape)
df = df.ix[df['status'] != 'unknown', :]
print(df.shape)

# clean up age
print(df.shape)
df = df.ix[~df['age'].isin(['unknown', 'unspecified', 'NA']), :]
print(df.shape)

# some customer changes that are hard to correct
df.ix[df['age'] == '12 (season 2)  13 (season 3)[1]  14 (season 4)', 'age'] = '10'
df.ix[df['age'] == 'one week ("the suicide king")8 months (season 5)9 months/11 months (season 6)', 'age'] = '0'
df.ix[df['age'] == '16 (season 2)17 (season 3)18 (season 5)', 'age'] = '10'
df.ix[df['age'] == '36 (season 1)37 (season 3)', 'age'] = '30'
df.ix[df['age'] == '7-10', 'age'] = '10'
df.ix[df['age'] == '8-10', 'age'] = '10'
df.ix[df['age'] == 'possibly 5-10', 'age'] = '10'
df.ix[df['age'] == '22  (season 2)23 (season 3)24 (season 4)', 'age'] = '20'

# keeps just the digits
df['age'] = df['age'].str.replace('[^0-9]', '')

# simpliys multiple ages to just a single age
df.ix[df['age'].str.len() == 4, 'age'] = df.ix[df['age'].str.len() == 4, 'age'].str[2:]

# converts the ages to numbers and rounds them down
df = df.ix[df['age'] != '', :]
df['age'] = df['age'].astype(int)
df['age'] = df['age'].round(-1)
print(df['age'].unique())

df.head()
# Out:
# (268, 9)
# (242, 9)
# (242, 9)
# (234, 9)
# [40 10  0 30 20 60 50 70 80]
#             name  gender                  hair  age           ethnicity  \
# 0    Rick Grimes    male  dark brown (greying)   40  caucasian-american
# 1    Carl Grimes    male                 brown   10  caucasian-american
# 2  Judith Grimes  female          honey blonde    0  caucasian-american
# 3    Lori Grimes  female                 brown   30  caucasian-american
# 5    Shane Walsh    male                 black   30  caucasian-american
#
#   status                     series lifespan  start_episode    end_episode
# 0  alive          "days gone bye" to present  days gone bye        present
# 1  alive          "days gone bye" to present  days gone bye        present
# 2  alive          "killer within" to present  killer within        present
# 3   dead  "days gone bye" to "killer within"  days gone bye  killer within
# 5   dead  "days gone bye" to "better angels"  days gone bye  better angels

# %%
# calculates thier series age
df['series_age'] = 0

# merges in the start episode number
df_full = df.merge(df_episodes.ix[:, ['episode_number', 'episode_name']], left_on = 'start_episode', right_on = 'episode_name', how = 'left')
df_full = df_full.drop('episode_name', 1)

# merges in the end episode number
df_full = df_full.merge(df_episodes.ix[:, ['episode_number', 'episode_name']], left_on = 'end_episode', right_on = 'episode_name', how = 'left')
df_full = df_full.drop('episode_name', 1)

# takes care of caracters that are still alive
df_full.ix[pd.isnull(df_full['episode_number_y']), 'episode_number_y'] = max(df_episodes['episode_number'])

# calculates the ages, we add a 1 so that if they lived 1 episode then they have an age of 1
df_full.ix[:, 'series_age'] = df_full['episode_number_y'] - df_full['episode_number_x'] + 1

# merges in the season they started in
df_full = df_full.merge(df_episodes.ix[:, ['season_number', 'episode_name']], left_on = 'start_episode', right_on = 'episode_name', how = 'left')
df_full.rename(columns={'season_number': 'season_birth'}, inplace=True)

# drops the extra column
df_full = df_full.drop(['episode_number_x', 'episode_number_y'], 1)

# drops the na's because we don't have clear data on how long they lived
print(df_full.shape)
df_full = df_full.ix[pd.notnull(df_full['series_age']), :]
print(df_full.shape)
# Out:
# (227, 12)
# (157, 12)

# %%
# simplifies the ethnicity
df_full.ix[df_full['ethnicity'] == 'african-american', 'ethnicity'] = 'black'
df_full.ix[df_full['ethnicity'] == 'hispanic-american', 'ethnicity'] = 'hispanic'
df_full.ix[df_full['ethnicity'] == 'indian-american', 'ethnicity'] = 'indian'
df_full.ix[df_full['ethnicity'] == 'asian-american', 'ethnicity'] = 'asian'
df_full.ix[df_full['ethnicity'] == 'korean-american', 'ethnicity'] = 'asian'
df_full.ix[df_full.ix[:, 'ethnicity'].isin(['caucasian-american', 'irish-american', 'caucasian', \
                                      'italian-american', 'caucasian-irish']), 'ethnicity'] = 'white'
# drops the nulls for ethnicity
df_full = df_full.ix[df_full['ethnicity'] != 'NA', :]
print(df_full['ethnicity'].unique())
df_full.head()
# Out:
# ['white' 'black' 'asian' 'hispanic' 'indian']
#             name  gender                  hair  age ethnicity status  \
# 0    Rick Grimes    male  dark brown (greying)   40     white  alive
# 1    Carl Grimes    male                 brown   10     white  alive
# 2  Judith Grimes  female          honey blonde    0     white  alive
# 3    Lori Grimes  female                 brown   30     white   dead
# 4    Shane Walsh    male                 black   30     white   dead
#
#                       series lifespan  start_episode    end_episode  \
# 0          "days gone bye" to present  days gone bye        present
# 1          "days gone bye" to present  days gone bye        present
# 2          "killer within" to present  killer within        present
# 3  "days gone bye" to "killer within"  days gone bye  killer within
# 4  "days gone bye" to "better angels"  days gone bye  better angels
#
#    series_age  season_birth   episode_name
# 0        83.0           1.0  days gone bye
# 1        83.0           1.0  days gone bye
# 2        61.0           3.0  killer within
# 3        23.0           1.0  days gone bye
# 4        18.0           1.0  days gone bye

# %% [markdown]
# # Modeling

# %%
x_variables = ['male', 'female', 'age', 'asian', 'black', 'hispanic', 'white', 'season_birth']

df_model = df_full.ix[:, ['name', 'gender', 'age', 'ethnicity', 'series_age', 'season_birth', 'status']].reset_index(drop = True)

# some manual one hot encoding
## gender
df_model['male'] = 0
df_model.ix[df_model['gender'] == 'male', 'male'] = 1
df_model['female'] = 0
df_model.ix[df_model['gender'] == 'female', 'female'] = 1

## ethnicity
for e in df_model['ethnicity'].unique():
    df_model[e] = 0
    df_model.ix[df_model['ethnicity'] == e, e] = 1

# # season they started in
# for s in df_model['season_birth'].unique():
#     df_model['season_birth_' + str(int(s))] = 0
#     df_model.ix[df_model['season_birth'] == s, 'season_birth_' + str(int(s))] = 1

# %%
# splits the data into characters we want to predict on and all other
df_model_characters = df_model.ix[df_model['name'].isin(character_list), :]
df_model_characters.drop('status', 1)
df_model = df_model.ix[df_model['status'].isin(['dead', 'undead']), :]
df_model.drop('status', 1)

# splits the data into x and y
df_x = df_model.ix[:, x_variables]
df_y = df_model.ix[:, ['series_age']]

# %%
# makes a data frame for storing predictions
x_characters = df_model_characters.ix[:, x_variables]
y_characters = df_model_characters.ix[:, ['series_age']]
df_predictions = pd.DataFrame(df_model_characters['name'], columns = ['name'])
df_predictions['series_age'] = y_characters

# %%
# tree
tree_model = tree.DecisionTreeRegressor(min_samples_leaf = 3)
tree_model.fit(df_x, df_y)
y_hat = tree_model.predict(x_characters)
df_predictions['tree_y_hat'] = y_hat
df_predictions['tree_y_hat_diff'] = df_predictions['tree_y_hat'] - df_predictions['series_age']

df_predictions.head(11)
# Out:
#                 name  series_age  tree_y_hat  tree_y_hat_diff
# 0        Rick Grimes        83.0    3.250000       -79.750000
# 1        Carl Grimes        83.0   19.333333       -63.666667
# 7         Glenn Rhee        83.0    7.000000       -76.000000
# 15       Daryl Dixon        81.0    3.250000       -77.750000
# 20     Maggie Greene        76.0    5.000000       -71.000000
# 27          Michonne        65.0   13.500000       -51.500000
# 49    Sasha Williams        57.0   13.500000       -43.500000
# 70     Eugene Porter        39.0    3.666667       -35.333333
# 71   Rosita Espinosa        39.0    7.200000       -31.800000
# 72      Abraham Ford        39.0    3.714286       -35.285714
# 102            Aaron        23.0    4.714286       -18.285714

# %%
# saves a pdf of the tree
from sklearn.externals.six import StringIO  

# saves the tree
dot_data = StringIO()
tree.export_graphviz(tree_model,
                     feature_names=df_x.columns,
                     filled = True,
                     rounded = True,
                     out_file=dot_data) 
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf('../viz/tree_model.pdf')
# Out:
# True
